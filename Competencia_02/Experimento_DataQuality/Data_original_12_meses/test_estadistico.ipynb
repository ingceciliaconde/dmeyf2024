# %%
# Restarting the necessary imports and running the analysis again
import pandas as pd
from scipy.stats import wilcoxon

# Data from the image provided
data = {
    "corte": [9000, 9500, 10000, 10500, 11000, 11500, 12000, 12500, 13000, 13500],
    "12_meses": [110694, 112958, 110344, 110368, 108034, 107241, 107591, 107334, 106401, 104907],
    "12_meses_QA": [75987, 72520, 73755, 72917, 73827, 74504, 73500, 71447, 72777, 70000]
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Performing Wilcoxon signed-rank test
stat, p_value = wilcoxon(df["12_meses"], df["12_meses_QA"])

stat, p_value
# Out:
# (0.0, 0.001953125)

# %%
#resumen del test
# H0: There is no difference between the two groups
# H1: There is a difference between the two groups

# p_value < 0.05: Reject the null hypothesis
# p_value > 0.05: Fail to reject the null hypothesis
resumen del stat vilcoxon   

# stat < 0: The first group is greater than the second group

# stat > 0: The second group is greater than the first group
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 summary("Wilcoxon signed-rank test", p_value)
#
# NameError: name 'summary' is not defined
